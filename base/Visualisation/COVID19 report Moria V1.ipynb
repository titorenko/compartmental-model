# %%
from IPython.display import HTML, display, Image
from preprocess import read_preprocess_file
from tables import *
from plots import *
#load in the unmitigated simulation
baseline=read_preprocess_file('./model_outcomes'+'/baseline.csv')

# %% [markdown]
# #### Disclaimer: This report is a draft report from AI for Good Simulator on the COVID-19 situation in Moria camp, Lesbos, Greece. The insights are preliminary and they are subject to future model fixes and improvements on parameter values

# %% [markdown]
# # AI for Good Simulator Model Report for Moria Camp

# %% [markdown]
# ## 0. Glossary
# * **hospitalisation/critical care demand person days**: The residents go into the hospitalisation/critical stage signify they require care but they may not receive the care depending on the capacity so this aggregates the hospitalisation/critical demand by person times number of days. If a unit cost of care is known, the total medical expense can be calculated.
# * **IQR (interquartile range)**: The output of modelling are represented as Interquartile range representing a confidence interval of 25%-75%.

# %% [markdown]
# ## 1. Overview

# %% [markdown]
# This report provides simulation-based estimates for COVID-19 epidemic scenarios for the Moria camp, one of the largest refugee camps in Europe, located on Lesbos, an island in Greece. There are an estimated 20,000 people currently living in the camp. Through epidemiology simulations, we estimated peak counts, the timing of peak counts as well as cumulative counts for new symptomatic cases, hospitalisation demand person-days, critical care demand person-days and deaths for an unmitigated epidemic.  Then we compare the results with different combinations of intervention strategies in place to:
# * Compare the potential efficacies of different interventions and prioritise the ones that are going to help contain the virus.
# * Have a realistic estimate of the clinic capacity, PPE, ICU transfer and other supplies and logistical measures needed

# %% [markdown]
# The graph below represents the disease transition dynamics for each individual included in the modelling studies. The model we use is a deterministic, age-specific compartment model. We produce the analysis based on 1000 simulation runs over a range of possible parameters

# %%
Image(filename='model.png',width=700,height=700) #not the most up-to-date diagram pending an update

# %% [markdown]
# The deterministic compartmental model requires:
# * Camp specific parameters: population size and age structure of the residents.
# * COVID specific parameters*: asymptomatic infection rate, days remaining infectious, etc.

# %%
population_breakdown()
# Out:
# <style  type="text/css" >
#     #T_0a923406_a67d_11ea_b574_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_0a923406_a67d_11ea_b574_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_0a923406_a67d_11ea_b574_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_0a923406_a67d_11ea_b574_acbc32839263" ><caption>Population breakdown of Moria camp with 18700 residents</caption><thead>    <tr>        <th class="col_heading level0 col0" >Age</th>        <th class="col_heading level0 col1" >Population_structure</th>        <th class="col_heading level0 col2" >Number of residents</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_0a923406_a67d_11ea_b574_acbc32839263row0_col0" class="data row0 col0" >0-9</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row0_col1" class="data row0 col1" >21.1%</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row0_col2" class="data row0 col2" >3936</td>
#             </tr>
#             <tr>
#                                 <td id="T_0a923406_a67d_11ea_b574_acbc32839263row1_col0" class="data row1 col0" >10-19</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row1_col1" class="data row1 col1" >17.3%</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row1_col2" class="data row1 col2" >3243</td>
#             </tr>
#             <tr>
#                                 <td id="T_0a923406_a67d_11ea_b574_acbc32839263row2_col0" class="data row2 col0" >20-29</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row2_col1" class="data row2 col1" >26.4%</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row2_col2" class="data row2 col2" >4927</td>
#             </tr>
#             <tr>
#                                 <td id="T_0a923406_a67d_11ea_b574_acbc32839263row3_col0" class="data row3 col0" >30-39</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row3_col1" class="data row3 col1" >17.2%</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row3_col2" class="data row3 col2" >3209</td>
#             </tr>
#             <tr>
#                                 <td id="T_0a923406_a67d_11ea_b574_acbc32839263row4_col0" class="data row4 col0" >40-49</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row4_col1" class="data row4 col1" >9.2%</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row4_col2" class="data row4 col2" >1728</td>
#             </tr>
#             <tr>
#                                 <td id="T_0a923406_a67d_11ea_b574_acbc32839263row5_col0" class="data row5 col0" >50-59</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row5_col1" class="data row5 col1" >5.5%</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row5_col2" class="data row5 col2" >1038</td>
#             </tr>
#             <tr>
#                                 <td id="T_0a923406_a67d_11ea_b574_acbc32839263row6_col0" class="data row6 col0" >60-69</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row6_col1" class="data row6 col1" >2.5%</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row6_col2" class="data row6 col2" >475</td>
#             </tr>
#             <tr>
#                                 <td id="T_0a923406_a67d_11ea_b574_acbc32839263row7_col0" class="data row7 col0" >70+</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row7_col1" class="data row7 col1" >0.8%</td>
#                         <td id="T_0a923406_a67d_11ea_b574_acbc32839263row7_col2" class="data row7 col2" >144</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# In Moria, it is estimated that 65% of the residents are below the age of 30 and that will lead to a relatively low death numbers but a high number of assympomatic infections.

# %% [markdown]
# Epidemiology simulations produce peak prevalence, the timing of peak prevalence as well as cumulative incidences for:
# * Symptomatic cases of infection
# * Hospitalisation demand person-days
# * Critical care demand person-days
# * Deaths

# %% [markdown]
# ## 2. Unmitigated COVID-19 Epidemic Trajectory

# %% [markdown]
# Here we assume the epidemic spreads through the camp without any non-pharmaceutical intervention in place and the peak incidence (number of cases), the timing and the cumulative case counts are all presented by interquartile range values (25%-75% quantiles) and they respectively represent the optimistic and pessimistic estimates of the spread of the virus given the uncertainty in parameters estimated from epidemiological studies. In the simulations, we explore a range of reproduction numbers, pre-symptomatic duration, rate of recovery, rate of severe infections and death rates based on estimates in the European and Asian settings to nearly what is estimated from a high population density location like a cruise ship.

# %%
prevalence_table_all=prevalence_all_table(baseline);prevalence_table_all
# Out:
# <style  type="text/css" >
#     #T_0d22c35c_a67d_11ea_b574_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_0d22c35c_a67d_11ea_b574_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_0d22c35c_a67d_11ea_b574_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_0d22c35c_a67d_11ea_b574_acbc32839263" ><caption>Peak day and peak number for prevalences of different disease states of COVID19</caption><thead>    <tr>        <th class="col_heading level0 col0" >Outcome</th>        <th class="col_heading level0 col1" >Peak Day IQR</th>        <th class="col_heading level0 col2" >Peak Number IQR</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_0d22c35c_a67d_11ea_b574_acbc32839263row0_col0" class="data row0 col0" >Prevalence of Symptomatic Cases</td>
#                         <td id="T_0d22c35c_a67d_11ea_b574_acbc32839263row0_col1" class="data row0 col1" >46-68</td>
#                         <td id="T_0d22c35c_a67d_11ea_b574_acbc32839263row0_col2" class="data row0 col2" >1422-2228</td>
#             </tr>
#             <tr>
#                                 <td id="T_0d22c35c_a67d_11ea_b574_acbc32839263row1_col0" class="data row1 col0" >Hospitalisation Demand</td>
#                         <td id="T_0d22c35c_a67d_11ea_b574_acbc32839263row1_col1" class="data row1 col1" >53-76</td>
#                         <td id="T_0d22c35c_a67d_11ea_b574_acbc32839263row1_col2" class="data row1 col2" >44-66</td>
#             </tr>
#             <tr>
#                                 <td id="T_0d22c35c_a67d_11ea_b574_acbc32839263row2_col0" class="data row2 col0" >Critical Care Demand</td>
#                         <td id="T_0d22c35c_a67d_11ea_b574_acbc32839263row2_col1" class="data row2 col1" >55-78</td>
#                         <td id="T_0d22c35c_a67d_11ea_b574_acbc32839263row2_col2" class="data row2 col2" >8-10</td>
#             </tr>
#             <tr>
#                                 <td id="T_0d22c35c_a67d_11ea_b574_acbc32839263row3_col0" class="data row3 col0" >Prevalence of Deaths</td>
#                         <td id="T_0d22c35c_a67d_11ea_b574_acbc32839263row3_col1" class="data row3 col1" >55-79</td>
#                         <td id="T_0d22c35c_a67d_11ea_b574_acbc32839263row3_col2" class="data row3 col2" >2-2</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# The peak number of infections is likely to be in the thousands, easily overwhelming the care capacity of the normal clinics within the camp and this could occur one and a half month after the virus first appears in the camp. The prevalence of hospitalisation, critical condition and death estimated are low: the peak hospitalisation demand will be 40-70 a day and the death estimate is based on the fact the patients require critical care will receive appropriate treatment from the 6 ICU beds that are currently available on Lesbos. The prevalence of death could be as high as the peak critical care demand (8-10) if camp residents are denied treatment at the ICU facility on the island.

# %%
prevalence_table_age=prevalence_age_table(baseline);prevalence_table_age
# Out:
# <style  type="text/css" >
#     #T_239027c4_a67d_11ea_b574_acbc32839263 th {
#           font-size: 15px;
#     }    #T_239027c4_a67d_11ea_b574_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_239027c4_a67d_11ea_b574_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_239027c4_a67d_11ea_b574_acbc32839263" ><caption>Peak day and peak prevalences of different disease states of COVID19 breakdown by age</caption><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Peak Day, IQR</th>        <th class="col_heading level0 col1" >Peak Number, IQR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_239027c4_a67d_11ea_b574_acbc32839263level0_row0" class="row_heading level0 row0" rowspan=9>Incident Cases</th>
#                         <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row0" class="row_heading level1 row0" >all ages</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row0_col0" class="data row0 col0" >46-68</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row0_col1" class="data row0 col1" >1422-2228</td>
#             </tr>
#             <tr>
#                                 <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row1" class="row_heading level1 row1" ><9 years</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row1_col0" class="data row1 col0" >48-72</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row1_col1" class="data row1 col1" >253-419</td>
#             </tr>
#             <tr>
#                                 <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row2" class="row_heading level1 row2" >10-19 years</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row2_col0" class="data row2 col0" >44-66</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row2_col1" class="data row2 col1" >350-536</td>
#             </tr>
#             <tr>
#                                 <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row3" class="row_heading level1 row3" >20-29 years</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row3_col0" class="data row3 col0" >45-68</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row3_col1" class="data row3 col1" >424-659</td>
#             </tr>
#             <tr>
#                                 <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row4" class="row_heading level1 row4" >30-39 years</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row4_col0" class="data row4 col0" >45-68</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row4_col1" class="data row4 col1" >255-396</td>
#             </tr>
#             <tr>
#                                 <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row5" class="row_heading level1 row5" >40-49 years</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row5_col0" class="data row5 col0" >46-69</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row5_col1" class="data row5 col1" >106-169</td>
#             </tr>
#             <tr>
#                                 <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row6" class="row_heading level1 row6" >50-59 years</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row6_col0" class="data row6 col0" >47-70</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row6_col1" class="data row6 col1" >48-78</td>
#             </tr>
#             <tr>
#                                 <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row7" class="row_heading level1 row7" >60-69 years</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row7_col0" class="data row7 col0" >50-74</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row7_col1" class="data row7 col1" >10-18</td>
#             </tr>
#             <tr>
#                                 <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row8" class="row_heading level1 row8" >70+ years</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row8_col0" class="data row8 col0" >50-73</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row8_col1" class="data row8 col1" >3-5</td>
#             </tr>
#             <tr>
#                         <th id="T_239027c4_a67d_11ea_b574_acbc32839263level0_row9" class="row_heading level0 row9" rowspan=9>Hospital Demand</th>
#                         <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row9" class="row_heading level1 row9" >all ages</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row9_col0" class="data row9 col0" >53-76</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row9_col1" class="data row9 col1" >44-66</td>
#             </tr>
#             <tr>
#                                 <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row10" class="row_heading level1 row10" ><9 years</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row10_col0" class="data row10 col0" >55-79</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row10_col1" class="data row10 col1" >3-4</td>
#             </tr>
#             <tr>
#                                 <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row11" class="row_heading level1 row11" >10-19 years</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row11_col0" class="data row11 col0" >49-72</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row11_col1" class="data row11 col1" >4-6</td>
#             </tr>
#             <tr>
#                                 <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row12" class="row_heading level1 row12" >20-29 years</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row12_col0" class="data row12 col0" >51-74</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row12_col1" class="data row12 col1" >6-9</td>
#             </tr>
#             <tr>
#                                 <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row13" class="row_heading level1 row13" >30-39 years</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row13_col0" class="data row13 col0" >51-74</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row13_col1" class="data row13 col1" >7-10</td>
#             </tr>
#             <tr>
#                                 <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row14" class="row_heading level1 row14" >40-49 years</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row14_col0" class="data row14 col0" >52-76</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row14_col1" class="data row14 col1" >8-12</td>
#             </tr>
#             <tr>
#                                 <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row15" class="row_heading level1 row15" >50-59 years</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row15_col0" class="data row15 col0" >53-77</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row15_col1" class="data row15 col1" >10-16</td>
#             </tr>
#             <tr>
#                                 <th id="T_239027c4_a67d_11ea_b574_acbc32839263level1_row16" class="row_heading level1 row16" >60-69 years</th>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row16_col0" class="data row16 col0" >56-80</td>
#                         <td id="T_239027c4_a67d_11ea_b574_acbc32839263row16_col1" class="data row16 col1" >5-8</td>
#             </tr>
#             <tr>

# %% [markdown]
# The age breakdown for the peak incidence shows that during the peak infection, residents aged below the age of 40 will comprise of more than 85% of the symptomatic infections while more than half of the people require hospitalisation on any given day will be above the age of 40. Noted that these estimates all project peak of the epidemic to be a month and a half since the first case of COVID19, giving local residents a period of time to react and try to curb the spread of the virus. Noted that the virus could be present in the camp without being noticed until the first death occurrence which is projected to be one month after the virus arrives at the camp.

# %%
comulative_table_all=cumulative_all_table(baseline);comulative_table_all
# Out:
# <style  type="text/css" >
#     #T_9b8f6d48_a67d_11ea_90af_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_9b8f6d48_a67d_11ea_90af_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_9b8f6d48_a67d_11ea_90af_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_9b8f6d48_a67d_11ea_90af_acbc32839263" ><caption>Cumulative case counts of different disease states of COVID19</caption><thead>    <tr>        <th class="col_heading level0 col0" >Totals</th>        <th class="col_heading level0 col1" >Counts</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9b8f6d48_a67d_11ea_90af_acbc32839263row0_col0" class="data row0 col0" >Symptomatic Cases</td>
#                         <td id="T_9b8f6d48_a67d_11ea_90af_acbc32839263row0_col1" class="data row0 col1" >6422-7071</td>
#             </tr>
#             <tr>
#                                 <td id="T_9b8f6d48_a67d_11ea_90af_acbc32839263row1_col0" class="data row1 col0" >Hospital Person-Days</td>
#                         <td id="T_9b8f6d48_a67d_11ea_90af_acbc32839263row1_col1" class="data row1 col1" >1742-2158</td>
#             </tr>
#             <tr>
#                                 <td id="T_9b8f6d48_a67d_11ea_90af_acbc32839263row2_col0" class="data row2 col0" >Critical Person-days</td>
#                         <td id="T_9b8f6d48_a67d_11ea_90af_acbc32839263row2_col1" class="data row2 col1" >436-497</td>
#             </tr>
#             <tr>
#                                 <td id="T_9b8f6d48_a67d_11ea_90af_acbc32839263row3_col0" class="data row3 col0" >Deaths</td>
#                         <td id="T_9b8f6d48_a67d_11ea_90af_acbc32839263row3_col1" class="data row3 col1" >59-68</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Looking at the cumulative counts in the course of the simulation spanning 200 days since the arrival of the virus, more than one-third of the camp residents are expected to be symptomatically infected by the virus and the total hospital person-days will be over 1750 person-days which places a huge demand on the hospital. This can be translated into projected medical costs or time required from medical staff if the medical cost and time taken is known for treating one patient for a day.

# %%
count_table_age=cumulative_age_table(baseline);count_table_age
# Out:
# <style  type="text/css" >
#     #T_12a24b1c_a67e_11ea_8481_acbc32839263 th {
#           font-size: 15px;
#     }    #T_12a24b1c_a67e_11ea_8481_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_12a24b1c_a67e_11ea_8481_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_12a24b1c_a67e_11ea_8481_acbc32839263" ><caption>Cumulative case counts of different disease states of COVID19 breakdown by age</caption><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >First month</th>        <th class="col_heading level0 col1" >First three months</th>        <th class="col_heading level0 col2" >First six months</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12a24b1c_a67e_11ea_8481_acbc32839263level0_row0" class="row_heading level0 row0" rowspan=9>Symptomatic Cases</th>
#                         <th id="T_12a24b1c_a67e_11ea_8481_acbc32839263level1_row0" class="row_heading level1 row0" >all ages</th>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row0_col0" class="data row0 col0" >82-767</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row0_col1" class="data row0 col1" >6162-7062</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row0_col2" class="data row0 col2" >6421-7071</td>
#             </tr>
#             <tr>
#                                 <th id="T_12a24b1c_a67e_11ea_8481_acbc32839263level1_row1" class="row_heading level1 row1" ><9 years</th>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row1_col0" class="data row1 col0" >10-99</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row1_col1" class="data row1 col1" >1150-1432</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row1_col2" class="data row1 col2" >1233-1436</td>
#             </tr>
#             <tr>
#                                 <th id="T_12a24b1c_a67e_11ea_8481_acbc32839263level1_row2" class="row_heading level1 row2" >10-19 years</th>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row2_col0" class="data row2 col0" >14-128</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row2_col1" class="data row2 col1" >748-799</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row2_col2" class="data row2 col2" >763-800</td>
#             </tr>
#             <tr>
#                                 <th id="T_12a24b1c_a67e_11ea_8481_acbc32839263level1_row3" class="row_heading level1 row3" >20-29 years</th>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row3_col0" class="data row3 col0" >24-223</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row3_col1" class="data row3 col1" >1624-1781</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row3_col2" class="data row3 col2" >1672-1782</td>
#             </tr>
#             <tr>
#                                 <th id="T_12a24b1c_a67e_11ea_8481_acbc32839263level1_row4" class="row_heading level1 row4" >30-39 years</th>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row4_col0" class="data row4 col0" >17-161</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row4_col1" class="data row4 col1" >1205-1320</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row4_col2" class="data row4 col2" >1242-1321</td>
#             </tr>
#             <tr>
#                                 <th id="T_12a24b1c_a67e_11ea_8481_acbc32839263level1_row5" class="row_heading level1 row5" >40-49 years</th>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row5_col0" class="data row5 col0" >9-88</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row5_col1" class="data row5 col1" >735-841</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row5_col2" class="data row5 col2" >765-842</td>
#             </tr>
#             <tr>
#                                 <th id="T_12a24b1c_a67e_11ea_8481_acbc32839263level1_row6" class="row_heading level1 row6" >50-59 years</th>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row6_col0" class="data row6 col0" >5-49</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row6_col1" class="data row6 col1" >466-561</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row6_col2" class="data row6 col2" >491-562</td>
#             </tr>
#             <tr>
#                                 <th id="T_12a24b1c_a67e_11ea_8481_acbc32839263level1_row7" class="row_heading level1 row7" >60-69 years</th>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row7_col0" class="data row7 col0" >1-14</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row7_col1" class="data row7 col1" >178-248</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row7_col2" class="data row7 col2" >194-249</td>
#             </tr>
#             <tr>
#                                 <th id="T_12a24b1c_a67e_11ea_8481_acbc32839263level1_row8" class="row_heading level1 row8" >70+ years</th>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row8_col0" class="data row8 col0" >0-4</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row8_col1" class="data row8 col1" >56-79</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row8_col2" class="data row8 col2" >61-79</td>
#             </tr>
#             <tr>
#                         <th id="T_12a24b1c_a67e_11ea_8481_acbc32839263level0_row9" class="row_heading level0 row9" rowspan=9>Hospital Person-Days</th>
#                         <th id="T_12a24b1c_a67e_11ea_8481_acbc32839263level1_row9" class="row_heading level1 row9" >all ages</th>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row9_col0" class="data row9 col0" >4-24</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row9_col1" class="data row9 col1" >1289-2006</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row9_col2" class="data row9 col2" >1741-2157</td>
#             </tr>
#             <tr>
#                                 <th id="T_12a24b1c_a67e_11ea_8481_acbc32839263level1_row10" class="row_heading level1 row10" ><9 years</th>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row10_col0" class="data row10 col0" >0-1</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row10_col1" class="data row10 col1" >74-129</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row10_col2" class="data row10 col2" >111-140</td>
#             </tr>
#             <tr>
#                                 <th id="T_12a24b1c_a67e_11ea_8481_acbc32839263level1_row11" class="row_heading level1 row11" >10-19 years</th>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row11_col0" class="data row11 col0" >0-3</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row11_col1" class="data row11 col1" >119-162</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row11_col2" class="data row11 col2" >142-173</td>
#             </tr>
#             <tr>
#                                 <th id="T_12a24b1c_a67e_11ea_8481_acbc32839263level1_row12" class="row_heading level1 row12" >20-29 years</th>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row12_col0" class="data row12 col0" >1-4</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row12_col1" class="data row12 col1" >172-247</td>
#                         <td id="T_12a24b1c_a67e_11ea_8481_acbc32839263row12_col2" class="data row12 col2" >217-265</td>
#             </tr>
#             <tr>

# %% [markdown]
# The cumulative incidence table for different disease status paints a similar picture compared to the peak prevalence table where younger residents account for most of the symptomatic infections but the older residents account for most of the hospitalisation/critical/death incidences. Most of the cases come from 2-3 months while in the first months the number of symptomatically infected people could range from 100 to 1000.

# %%
plot_all(baseline)

# %%
plot_by_age_all(baseline)

# %% [markdown]
# Visually comparing different age groups in different disease status, residents of age 50-59 are hit the hardest in terms of hopitatlisation, critical and deaths with residents of age 40-49 second in line. In terms of symptomatic infection, residents of age 20-29 are affected the worst with residents of age 10-19 second in line.

# %% [markdown]
# ## 2. Invervention scenarios

# %% [markdown]
# ### 2.1 Single intervention scenarios

# %% [markdown]
# We assumed these interventions are applied at the camp-wide level and they are assumed to have full coverage starting from a certain day that is specified by the simulation and there are five interventions that are currently implemented.
#
# * Improved handwashing, masks for everyone, general social distancing and other interventions that aim to reduce person-to-person transmission probabilities that are not location-specific belongs to this first group of intervention. Here we set the effectiveness of the intervention as anther variable: 10% reduction in transmission rate: somewhat effective, 20% reduction: effective, 30% reduction: very effective.
# * Move high-risk residents (age>60) offsite. Here we control the time periods that this is happening and the number of high-risk people being moved off-site each day during that time period.
# * Isolate symptomatically infected residents: here we assume the residents are isolated in a separate isolation centre off-site, therefore, the transmission between infected residents in these centres with anyone outside is cut off (we haven't factored in the case where detecting these individuals can have a period of delay and the isolation centres that are currently in place are inside the camp where people still share water points and toilets.)
# * Build up ICU bed capacity: we know that on the island of Lesbos there are only 6 ICU beds currently available so we explore the case of building up the ICU beds to 16,32 and 48 to see how that can have an effect. This will only have an impact on the death rate as this won't stop the contagion from spreading within the camp (in reality the ICU bed capacity requirement can be easily tracked through critical cases outlined in the previous section where patients require a treatment package.)
# * Shielding: where the high-risk residents (> 60-year-olds) are housed in a green zone in the camp facility and they self-manage the sector while the entry into the green zone is limited so the contact between older residents and younger residents are reduced.

# %% [markdown]
# Three high-level insights:
# 1. Reducing individual-level transmission via social distancing, masks and regular handwashing can result in decreasing up to 20% of all cases in the most optimistic scenario. Prioritising a longer, sustained program is arguably more important than prioritising a short-lived stringent program as it demonstrates that if a program is only effective for 1-2 months, it has minimal effect on curbing the cumulative number of the infectious cases other than delaying the peak infections by a few days.
# 2. Removing high-risk residents offsite early will not impact the total number of people infected but will reduce the hospitalisation need, critical care need and death incidences onsite by 10%.
# 3. Isolating symptomatically infected people until they are recovered (still need more investigation and tweaking) currently suggests that the capacity of the isolation centre is less important than having a long and rigorous surveillance program (one such program aims to isolate 10 people per day) (need further tweaking to see how much impact this have on the total number of people infected)

# %% [markdown]
# The plot below shows the top 5 single intervention scenarios for reducing peak numbers in each state in descending order:
# * Committing to the long-term 'isolation the symptomatically infected people' can help curb the epidemic in all categories and potentially coupled with contact tracing to encourage self-isolation of asymptomatically infected people who are in touch with them can further drive the numbers down.
# * Committing to the long-term social distancing/mask/handwashing can help curb the virus tremendously but we need to benchmark the effectiveness of these approaches (possibly by motion tracking or random surveys)
# * Removing high-risk residents have a big impact on driving on the death numbers and we have yet to model the effect of removing unaccompanied children off the island.

# %%
plot_one_intervention_vertical_interactive(plot_one_intervention_vertical)
# Out:
# interactive(children=(Select(description='Category:', options=('Infected (symptomatic)', 'Hospitalised', 'Crit…

# %% [markdown]
# The tables below from each intervention show the % net reduction to cases, deaths, and hospitalised person­days in these scenarios, 200 days after initial introduction in Moria.

# %% [markdown]
# ### 2.1.1 Improved personal hygiene (social distancing/PPE/regular handwashing)

# %% [markdown]
# We are exploring two factors here:
# * How effective will the intervention measures have to be the reduce the spread of the virus?
# * How long will such measures have to be in place for them to be effective?

# %%
effectiveness_cum_table_hygiene(baseline,timing=True)
# Out:
# <style  type="text/css" >
#     #T_a10238a2_a680_11ea_8481_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_a10238a2_a680_11ea_8481_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_a10238a2_a680_11ea_8481_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_a10238a2_a680_11ea_8481_acbc32839263" ><caption>Reduction in cumulative incidences of the same hygiene measures but with different timings</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 30</th>        <th class="col_heading level0 col1" >reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 60</th>        <th class="col_heading level0 col2" >reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 90</th>        <th class="col_heading level0 col3" >reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 200</th>    </tr>    <tr>        <th class="index_name level0" >Total</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a10238a2_a680_11ea_8481_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row0_col0" class="data row0 col0" >0%~0%</td>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row0_col1" class="data row0 col1" >1%~2%</td>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row0_col2" class="data row0 col2" >5%~7%</td>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row0_col3" class="data row0 col3" >9%~21%</td>
#             </tr>
#             <tr>
#                         <th id="T_a10238a2_a680_11ea_8481_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row1_col0" class="data row1 col0" >0%~0%</td>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row1_col1" class="data row1 col1" >1%~2%</td>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row1_col2" class="data row1 col2" >6%~6%</td>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row1_col3" class="data row1 col3" >13%~21%</td>
#             </tr>
#             <tr>
#                         <th id="T_a10238a2_a680_11ea_8481_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row2_col0" class="data row2 col0" >0%~0%</td>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row2_col1" class="data row2 col1" >-3%~-2%</td>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row2_col2" class="data row2 col2" >-5%~-4%</td>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row2_col3" class="data row2 col3" >0%~1%</td>
#             </tr>
#             <tr>
#                         <th id="T_a10238a2_a680_11ea_8481_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row3_col0" class="data row3 col0" >0%~0%</td>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row3_col1" class="data row3 col1" >2%~3%</td>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row3_col2" class="data row3 col2" >8%~10%</td>
#                         <td id="T_a10238a2_a680_11ea_8481_acbc32839263row3_col3" class="data row3 col3" >13%~29%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Here we explore how the duration of implementing such measures could have an impact on the number of cases reduced and lives saved. Clearly the longer personal hygiene measures are in place the better. Interesting to note that, if these improving hygiene measures are only implemented during the nascent period of the virus (first month) it won't have an impact on the spread of the virus at all. 2 months of applying the measures will yield a minimal reduction in accumulative numbers while implementing for 3+ months can really start yielding promising results in curbing the spread of the virus.

# %%
effectiveness_peak_table_hygiene(baseline,timing=True)
# Out:
# <style  type="text/css" >
#     #T_5fed0ef4_a681_11ea_a5c3_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_5fed0ef4_a681_11ea_a5c3_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_5fed0ef4_a681_11ea_a5c3_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263" ><caption>Delay and reduction in peak prevalence for same program with different lengths of implementation</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 30</th>        <th class="col_heading level0 col2" colspan=2>reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 60</th>        <th class="col_heading level0 col4" colspan=2>reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 90</th>        <th class="col_heading level0 col6" colspan=2>reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 200</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col1" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col2" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col3" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col4" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col5" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col6" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col7" >Reduction in Peak Number IQR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263level0_row0" class="row_heading level0 row0" >Prevalence of Symptomatic Cases</th>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row0_col0" class="data row0 col0" >10~13 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row0_col1" class="data row0 col1" >0%~0%</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row0_col2" class="data row0 col2" >21~26 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row0_col3" class="data row0 col3" >9%~17%</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row0_col4" class="data row0 col4" >19~41 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row0_col5" class="data row0 col5" >27%~32%</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row0_col6" class="data row0 col6" >18~37 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row0_col7" class="data row0 col7" >33%~48%</td>
#             </tr>
#             <tr>
#                         <th id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263level0_row1" class="row_heading level0 row1" >Hospitalisation Demand</th>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row1_col0" class="data row1 col0" >10~13 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row1_col1" class="data row1 col1" >0%~0%</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row1_col2" class="data row1 col2" >22~26 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row1_col3" class="data row1 col3" >2%~14%</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row1_col4" class="data row1 col4" >20~40 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row1_col5" class="data row1 col5" >23%~29%</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row1_col6" class="data row1 col6" >19~39 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row1_col7" class="data row1 col7" >29%~45%</td>
#             </tr>
#             <tr>
#                         <th id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Care Demand</th>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row2_col0" class="data row2 col0" >10~14 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row2_col1" class="data row2 col1" >0%~0%</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row2_col2" class="data row2 col2" >21~27 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row2_col3" class="data row2 col3" >10%~12%</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row2_col4" class="data row2 col4" >20~41 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row2_col5" class="data row2 col5" >12%~20%</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row2_col6" class="data row2 col6" >19~39 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row2_col7" class="data row2 col7" >20%~25%</td>
#             </tr>
#             <tr>
#                         <th id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263level0_row3" class="row_heading level0 row3" >Prevalence of Deaths</th>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row3_col0" class="data row3 col0" >11~13 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row3_col1" class="data row3 col1" >0%~0%</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row3_col2" class="data row3 col2" >22~26 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row3_col3" class="data row3 col3" >0%~50%</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row3_col4" class="data row3 col4" >20~41 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row3_col5" class="data row3 col5" >0%~50%</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row3_col6" class="data row3 col6" >20~39 days</td>
#                         <td id="T_5fed0ef4_a681_11ea_a5c3_acbc32839263row3_col7" class="data row3 col7" >0%~50%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Here we explore how such measures can have an impact on the peak incidences and the days in which they occur. Note that a short-lived measure can delay the onset of the epidemic by 10 days while a longer-lasting control measure can delay the epidemic by more than 3 weeks while reducing the peak incidences of symptomatic infections by a third.

# %%
plot_hygiene_intervention_horizontal(baseline)

# %%
effectiveness_cum_table_hygiene(baseline,timing=False)
# Out:
# <style  type="text/css" >
#     #T_de48bb4a_a681_11ea_a5c3_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_de48bb4a_a681_11ea_a5c3_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_de48bb4a_a681_11ea_a5c3_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_de48bb4a_a681_11ea_a5c3_acbc32839263" ><caption>Reduction in cumulative incidences of different levels of hygiene measures in the same time frame</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 200</th>        <th class="col_heading level0 col1" >reduce transmission by 20% by social distancing/mask/handwashing from day 0 to day 200</th>        <th class="col_heading level0 col2" >reduce transmission by 10% by social distancing/mask/handwashing from day 0 to day 200</th>    </tr>    <tr>        <th class="index_name level0" >Total</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_de48bb4a_a681_11ea_a5c3_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_de48bb4a_a681_11ea_a5c3_acbc32839263row0_col0" class="data row0 col0" >9%~21%</td>
#                         <td id="T_de48bb4a_a681_11ea_a5c3_acbc32839263row0_col1" class="data row0 col1" >5%~11%</td>
#                         <td id="T_de48bb4a_a681_11ea_a5c3_acbc32839263row0_col2" class="data row0 col2" >2%~5%</td>
#             </tr>
#             <tr>
#                         <th id="T_de48bb4a_a681_11ea_a5c3_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_de48bb4a_a681_11ea_a5c3_acbc32839263row1_col0" class="data row1 col0" >13%~21%</td>
#                         <td id="T_de48bb4a_a681_11ea_a5c3_acbc32839263row1_col1" class="data row1 col1" >7%~12%</td>
#                         <td id="T_de48bb4a_a681_11ea_a5c3_acbc32839263row1_col2" class="data row1 col2" >3%~5%</td>
#             </tr>
#             <tr>
#                         <th id="T_de48bb4a_a681_11ea_a5c3_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_de48bb4a_a681_11ea_a5c3_acbc32839263row2_col0" class="data row2 col0" >0%~1%</td>
#                         <td id="T_de48bb4a_a681_11ea_a5c3_acbc32839263row2_col1" class="data row2 col1" >-1%~0%</td>
#                         <td id="T_de48bb4a_a681_11ea_a5c3_acbc32839263row2_col2" class="data row2 col2" >-1%~0%</td>
#             </tr>
#             <tr>
#                         <th id="T_de48bb4a_a681_11ea_a5c3_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_de48bb4a_a681_11ea_a5c3_acbc32839263row3_col0" class="data row3 col0" >13%~29%</td>
#                         <td id="T_de48bb4a_a681_11ea_a5c3_acbc32839263row3_col1" class="data row3 col1" >7%~17%</td>
#                         <td id="T_de48bb4a_a681_11ea_a5c3_acbc32839263row3_col2" class="data row3 col2" >3%~7%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Here we explore how strict these hygiene measures should be and quite rightly so, the better you can do it, the better the results in minimising the impact of the virus. (Further points - how large should the program cover in the total population and what if some people conform and other people disobey social distancing/masks/hand washing)

# %%
effectiveness_peak_table_hygiene(baseline,timing=False)
# Out:
# <style  type="text/css" >
#     #T_ea55d47c_a681_11ea_a5c3_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_ea55d47c_a681_11ea_a5c3_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_ea55d47c_a681_11ea_a5c3_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_ea55d47c_a681_11ea_a5c3_acbc32839263" ><caption>Delay and reduction in peak prevalence for different programs with the same length of implementation</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>reduce transmission by 30% by social distancing/mask/handwashing from day 0 to day 200</th>        <th class="col_heading level0 col2" colspan=2>reduce transmission by 20% by social distancing/mask/handwashing from day 0 to day 200</th>        <th class="col_heading level0 col4" colspan=2>reduce transmission by 10% by social distancing/mask/handwashing from day 0 to day 200</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col1" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col2" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col3" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col4" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col5" >Reduction in Peak Number IQR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ea55d47c_a681_11ea_a5c3_acbc32839263level0_row0" class="row_heading level0 row0" >Prevalence of Symptomatic Cases</th>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row0_col0" class="data row0 col0" >18~37 days</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row0_col1" class="data row0 col1" >33%~48%</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row0_col2" class="data row0 col2" >10~21 days</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row0_col3" class="data row0 col3" >20%~31%</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row0_col4" class="data row0 col4" >4~8 days</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row0_col5" class="data row0 col5" >10%~14%</td>
#             </tr>
#             <tr>
#                         <th id="T_ea55d47c_a681_11ea_a5c3_acbc32839263level0_row1" class="row_heading level0 row1" >Hospitalisation Demand</th>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row1_col0" class="data row1 col0" >19~39 days</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row1_col1" class="data row1 col1" >29%~45%</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row1_col2" class="data row1 col2" >11~21 days</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row1_col3" class="data row1 col3" >17%~27%</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row1_col4" class="data row1 col4" >5~9 days</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row1_col5" class="data row1 col5" >8%~14%</td>
#             </tr>
#             <tr>
#                         <th id="T_ea55d47c_a681_11ea_a5c3_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Care Demand</th>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row2_col0" class="data row2 col0" >19~39 days</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row2_col1" class="data row2 col1" >20%~25%</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row2_col2" class="data row2 col2" >11~21 days</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row2_col3" class="data row2 col3" >10%~12%</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row2_col4" class="data row2 col4" >5~10 days</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row2_col5" class="data row2 col5" >0%~12%</td>
#             </tr>
#             <tr>
#                         <th id="T_ea55d47c_a681_11ea_a5c3_acbc32839263level0_row3" class="row_heading level0 row3" >Prevalence of Deaths</th>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row3_col0" class="data row3 col0" >20~39 days</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row3_col1" class="data row3 col1" >0%~50%</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row3_col2" class="data row3 col2" >11~21 days</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row3_col3" class="data row3 col3" >0%~50%</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row3_col4" class="data row3 col4" >5~9 days</td>
#                         <td id="T_ea55d47c_a681_11ea_a5c3_acbc32839263row3_col5" class="data row3 col5" >0%~50%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# A stricter measure can delay the onset of the epidemic by more than two weeks contrasting with a less strict measure delating onset by only less than a week.

# %%
plot_hygiene_intervention_horizontal(baseline,timing=False)

# %%
plot_onetype_intervention_vertical('hygiene')

# %% [markdown]
# Comparison among the plots (the most effective at the top) shows that prioritising a long-term, sustainable program is more important than having an effective yet short-lived one. There are no quick fixes here!

# %% [markdown]
# ### 2.1.2 Move high risk residents off-site

# %% [markdown]
# Here we assume that there are about 600 residents within the camp who can be classified as high risk (>age 60) so they should go into self-shielding or be moved off-site. We explore removing these residents at a different rate and how that can have an impact on the epidemic. (In reality, this is slowly happening for Moria but the rate of removing these high-risk residents is extremely slow because the authority is evacuating a whole family at a time.

# %%
effectiveness_cum_table_onetype(baseline,'highrisk',caption='Effect of removing high risk residents from the camp on cumulative cases of incidence',display=False)
# Out:
# <style  type="text/css" >
#     #T_63a371a4_a682_11ea_a5c3_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_63a371a4_a682_11ea_a5c3_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_63a371a4_a682_11ea_a5c3_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_63a371a4_a682_11ea_a5c3_acbc32839263" ><caption>Effect of removing high risk residents from the camp on cumulative cases of incidence</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >remove 100 high-risk residents from day 0 to day 6</th>        <th class="col_heading level0 col1" >remove 20 high-risk residents from day 0 to day 30</th>        <th class="col_heading level0 col2" >remove 50 high-risk residents from day 0 to day 12</th>    </tr>    <tr>        <th class="index_name level0" >Total</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_63a371a4_a682_11ea_a5c3_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_63a371a4_a682_11ea_a5c3_acbc32839263row0_col0" class="data row0 col0" >-3%~-2%</td>
#                         <td id="T_63a371a4_a682_11ea_a5c3_acbc32839263row0_col1" class="data row0 col1" >-3%~-2%</td>
#                         <td id="T_63a371a4_a682_11ea_a5c3_acbc32839263row0_col2" class="data row0 col2" >-3%~-2%</td>
#             </tr>
#             <tr>
#                         <th id="T_63a371a4_a682_11ea_a5c3_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_63a371a4_a682_11ea_a5c3_acbc32839263row1_col0" class="data row1 col0" >16%~16%</td>
#                         <td id="T_63a371a4_a682_11ea_a5c3_acbc32839263row1_col1" class="data row1 col1" >16%~17%</td>
#                         <td id="T_63a371a4_a682_11ea_a5c3_acbc32839263row1_col2" class="data row1 col2" >16%~17%</td>
#             </tr>
#             <tr>
#                         <th id="T_63a371a4_a682_11ea_a5c3_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_63a371a4_a682_11ea_a5c3_acbc32839263row2_col0" class="data row2 col0" >9%~10%</td>
#                         <td id="T_63a371a4_a682_11ea_a5c3_acbc32839263row2_col1" class="data row2 col1" >10%~10%</td>
#                         <td id="T_63a371a4_a682_11ea_a5c3_acbc32839263row2_col2" class="data row2 col2" >10%~10%</td>
#             </tr>
#             <tr>
#                         <th id="T_63a371a4_a682_11ea_a5c3_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_63a371a4_a682_11ea_a5c3_acbc32839263row3_col0" class="data row3 col0" >17%~19%</td>
#                         <td id="T_63a371a4_a682_11ea_a5c3_acbc32839263row3_col1" class="data row3 col1" >19%~19%</td>
#                         <td id="T_63a371a4_a682_11ea_a5c3_acbc32839263row3_col2" class="data row3 col2" >19%~19%</td>
#             </tr>
#     </tbody></table>

# %%
effectiveness_peak_table_onetype(baseline,'highrisk')
# Out:
# <style  type="text/css" >
#     #T_a3c281ae_a442_11ea_bf5b_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_a3c281ae_a442_11ea_bf5b_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_a3c281ae_a442_11ea_bf5b_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_a3c281ae_a442_11ea_bf5b_acbc32839263" ><caption>Table 3. Cumulative case counts of different disease states of COVID19</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>remove 100 high-risk residents from day 0 to day 6</th>        <th class="col_heading level0 col2" colspan=2>remove 50 high-risk residents from day 0 to day 12</th>        <th class="col_heading level0 col4" colspan=2>remove 20 high-risk residents from day 0 to day 30</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col1" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col2" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col3" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col4" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col5" >Reduction in Peak Number IQR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a3c281ae_a442_11ea_bf5b_acbc32839263level0_row0" class="row_heading level0 row0" >Incidence of Symptomatic Cases</th>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row0_col0" class="data row0 col0" >0~0 days</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row0_col1" class="data row0 col1" >1%~1%</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row0_col2" class="data row0 col2" >0~0 days</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row0_col3" class="data row0 col3" >1%~1%</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row0_col4" class="data row0 col4" >0~0 days</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row0_col5" class="data row0 col5" >1%~1%</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c281ae_a442_11ea_bf5b_acbc32839263level0_row1" class="row_heading level0 row1" >Hospitalisation Demand</th>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row1_col0" class="data row1 col0" >-1~-1 days</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row1_col1" class="data row1 col1" >14%~15%</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row1_col2" class="data row1 col2" >-1~-1 days</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row1_col3" class="data row1 col3" >15%~16%</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row1_col4" class="data row1 col4" >-1~-1 days</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row1_col5" class="data row1 col5" >15%~16%</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c281ae_a442_11ea_bf5b_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Care Demand</th>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row2_col0" class="data row2 col0" >-1~0 days</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row2_col1" class="data row2 col1" >10%~12%</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row2_col2" class="data row2 col2" >-1~0 days</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row2_col3" class="data row2 col3" >10%~12%</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row2_col4" class="data row2 col4" >-1~0 days</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row2_col5" class="data row2 col5" >10%~12%</td>
#             </tr>
#             <tr>
#                         <th id="T_a3c281ae_a442_11ea_bf5b_acbc32839263level0_row3" class="row_heading level0 row3" >Incidence of Deaths</th>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row3_col0" class="data row3 col0" >-1~0 days</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row3_col1" class="data row3 col1" >0%~50%</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row3_col2" class="data row3 col2" >-1~0 days</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row3_col3" class="data row3 col3" >0%~50%</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row3_col4" class="data row3 col4" >-1~0 days</td>
#                         <td id="T_a3c281ae_a442_11ea_bf5b_acbc32839263row3_col5" class="data row3 col5" >0%~50%</td>
#             </tr>
#     </tbody></table>

# %%
plot_onetype_intervention_horizontal(baseline,'highrisk','Deaths')

# %% [markdown]
# Removing high risk residents (age>60) offsite early will not impact the total number of people infected but will reduce the hospitalisation need, critical care need and death incidences onsite by 10-20%. The timing of it does not matter as long as the residents are removed before the peak of the epidemic.

# %% [markdown]
# ### 2.1.3 Isolate sympotomatically infected residents

# %% [markdown]
# Here we explore this intervention along two dimensions:
# * the capacity at which we can make sure the infected residents are isolated (5%,10%,20%,35%)
# * the detection/isolation rate at which such intervention is carried out (10,50,100 people per day)

# %%
cumulative_iso_table()
# Out:
# <style  type="text/css" >
#     #T_db1c4ea4_a759_11ea_9f21_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_db1c4ea4_a759_11ea_9f21_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_db1c4ea4_a759_11ea_9f21_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_db1c4ea4_a759_11ea_9f21_acbc32839263" ><caption>Cumulative number of Quarantine Person-Days for different isolation strategies COVID19</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Qurantined Person-Days</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_db1c4ea4_a759_11ea_9f21_acbc32839263level0_row0" class="row_heading level0 row0" >isolate symptomatically infected people at 50 people per day for 120 days</th>
#                         <td id="T_db1c4ea4_a759_11ea_9f21_acbc32839263row0_col0" class="data row0 col0" >53-3847</td>
#             </tr>
#             <tr>
#                         <th id="T_db1c4ea4_a759_11ea_9f21_acbc32839263level0_row1" class="row_heading level0 row1" >isolate symptomatically infected people at 50 people per day for 80 days</th>
#                         <td id="T_db1c4ea4_a759_11ea_9f21_acbc32839263row1_col0" class="data row1 col0" >42-695</td>
#             </tr>
#             <tr>
#                         <th id="T_db1c4ea4_a759_11ea_9f21_acbc32839263level0_row2" class="row_heading level0 row2" >isolate symptomatically infected people at 50 people per day for 40 days</th>
#                         <td id="T_db1c4ea4_a759_11ea_9f21_acbc32839263row2_col0" class="data row2 col0" >26-97</td>
#             </tr>
#             <tr>
#                         <th id="T_db1c4ea4_a759_11ea_9f21_acbc32839263level0_row3" class="row_heading level0 row3" >isolate symptomatically infected people at 50 people per day for 20 days</th>
#                         <td id="T_db1c4ea4_a759_11ea_9f21_acbc32839263row3_col0" class="data row3 col0" >15-30</td>
#             </tr>
#     </tbody></table>

# %%
The table above shows that the isolation intervention can be quite a resource intensive operation

# %%
effectiveness_cum_table_iso(baseline)
# Out:
# <style  type="text/css" >
#     #T_60e83236_a50d_11ea_b9d6_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_60e83236_a50d_11ea_b9d6_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_60e83236_a50d_11ea_b9d6_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_60e83236_a50d_11ea_b9d6_acbc32839263" ><caption>Effectiveness of the same isolation policy but with different lengths of implementation</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >isolate symptomatically infected people at 50 people per day for 20 days</th>        <th class="col_heading level0 col1" >isolate symptomatically infected people at 50 people per day for 40 days</th>        <th class="col_heading level0 col2" >isolate symptomatically infected people at 50 people per day for 80 days</th>        <th class="col_heading level0 col3" >isolate symptomatically infected people at 50 people per day for 120 days</th>    </tr>    <tr>        <th class="index_name level0" >Total</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_60e83236_a50d_11ea_b9d6_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row0_col0" class="data row0 col0" >0%~0%</td>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row0_col1" class="data row0 col1" >0%~0%</td>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row0_col2" class="data row0 col2" >0%~1%</td>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row0_col3" class="data row0 col3" >2%~24%</td>
#             </tr>
#             <tr>
#                         <th id="T_60e83236_a50d_11ea_b9d6_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row1_col0" class="data row1 col0" >0%~0%</td>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row1_col1" class="data row1 col1" >0%~1%</td>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row1_col2" class="data row1 col2" >2%~8%</td>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row1_col3" class="data row1 col3" >7%~70%</td>
#             </tr>
#             <tr>
#                         <th id="T_60e83236_a50d_11ea_b9d6_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row2_col0" class="data row2 col0" >0%~1%</td>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row2_col1" class="data row2 col1" >2%~3%</td>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row2_col2" class="data row2 col2" >4%~12%</td>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row2_col3" class="data row2 col3" >9%~76%</td>
#             </tr>
#             <tr>
#                         <th id="T_60e83236_a50d_11ea_b9d6_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row3_col0" class="data row3 col0" >0%~0%</td>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row3_col1" class="data row3 col1" >0%~2%</td>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row3_col2" class="data row3 col2" >1%~12%</td>
#                         <td id="T_60e83236_a50d_11ea_b9d6_acbc32839263row3_col3" class="data row3 col3" >7%~83%</td>
#             </tr>
#     </tbody></table>

# %%
effectiveness_peak_table_iso(baseline)
# Out:
# <style  type="text/css" >
#     #T_b345b62c_a682_11ea_a5c3_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_b345b62c_a682_11ea_a5c3_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_b345b62c_a682_11ea_a5c3_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_b345b62c_a682_11ea_a5c3_acbc32839263" ><caption>Placeholder</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>isolate symptomatically infected people at 50 people per day for 20 days</th>        <th class="col_heading level0 col2" colspan=2>isolate symptomatically infected people at 50 people per day for 40 days</th>        <th class="col_heading level0 col4" colspan=2>isolate symptomatically infected people at 50 people per day for 80 days</th>        <th class="col_heading level0 col6" colspan=2>isolate symptomatically infected people at 50 people per day for 120 days</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col1" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col2" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col3" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col4" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col5" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col6" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col7" >Reduction in Peak Number IQR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b345b62c_a682_11ea_a5c3_acbc32839263level0_row0" class="row_heading level0 row0" >Prevalence of Symptomatic Cases</th>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row0_col0" class="data row0 col0" >17~23 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row0_col1" class="data row0 col1" >0%~0%</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row0_col2" class="data row0 col2" >33~44 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row0_col3" class="data row0 col3" >0%~0%</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row0_col4" class="data row0 col4" >64~84 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row0_col5" class="data row0 col5" >3%~6%</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row0_col6" class="data row0 col6" >95~119 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row0_col7" class="data row0 col7" >13%~19%</td>
#             </tr>
#             <tr>
#                         <th id="T_b345b62c_a682_11ea_a5c3_acbc32839263level0_row1" class="row_heading level0 row1" >Hospitalisation Demand</th>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row1_col0" class="data row1 col0" >17~23 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row1_col1" class="data row1 col1" >0%~0%</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row1_col2" class="data row1 col2" >33~44 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row1_col3" class="data row1 col3" >0%~0%</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row1_col4" class="data row1 col4" >65~84 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row1_col5" class="data row1 col5" >0%~3%</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row1_col6" class="data row1 col6" >95~119 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row1_col7" class="data row1 col7" >11%~14%</td>
#             </tr>
#             <tr>
#                         <th id="T_b345b62c_a682_11ea_a5c3_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Care Demand</th>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row2_col0" class="data row2 col0" >17~24 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row2_col1" class="data row2 col1" >0%~0%</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row2_col2" class="data row2 col2" >33~44 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row2_col3" class="data row2 col3" >0%~0%</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row2_col4" class="data row2 col4" >64~85 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row2_col5" class="data row2 col5" >0%~12%</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row2_col6" class="data row2 col6" >95~119 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row2_col7" class="data row2 col7" >0%~12%</td>
#             </tr>
#             <tr>
#                         <th id="T_b345b62c_a682_11ea_a5c3_acbc32839263level0_row3" class="row_heading level0 row3" >Prevalence of Deaths</th>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row3_col0" class="data row3 col0" >18~23 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row3_col1" class="data row3 col1" >0%~0%</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row3_col2" class="data row3 col2" >34~44 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row3_col3" class="data row3 col3" >0%~0%</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row3_col4" class="data row3 col4" >65~84 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row3_col5" class="data row3 col5" >0%~0%</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row3_col6" class="data row3 col6" >96~119 days</td>
#                         <td id="T_b345b62c_a682_11ea_a5c3_acbc32839263row3_col7" class="data row3 col7" >0%~50%</td>
#             </tr>
#     </tbody></table>

# %%
plot_iso_intervention_horizontal(baseline)

# %%
plot_iso_intervention_horizontal(baseline,column='Quarantined')

# %%
effectiveness_cum_table_iso(baseline,timing=False)
# Out:
# <style  type="text/css" >
#     #T_de4a579c_a682_11ea_a5c3_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_de4a579c_a682_11ea_a5c3_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_de4a579c_a682_11ea_a5c3_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_de4a579c_a682_11ea_a5c3_acbc32839263" ><caption>Effectiveness of the isolation policies with different lengths of implementation and different daily capacity</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >isolate symptomatically infected people at 100 people per day for 20 days</th>        <th class="col_heading level0 col1" >isolate symptomatically infected people at 100 people per day for 30 days</th>        <th class="col_heading level0 col2" >isolate symptomatically infected people at 50 people per day for 40 days</th>        <th class="col_heading level0 col3" >isolate symptomatically infected people at 100 people per day for 60 days</th>        <th class="col_heading level0 col4" >isolate symptomatically infected people at 10 people per day for 100 days</th>        <th class="col_heading level0 col5" >isolate symptomatically infected people at 10 people per day for 200 days</th>    </tr>    <tr>        <th class="index_name level0" >Total</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_de4a579c_a682_11ea_a5c3_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row0_col0" class="data row0 col0" >0%~0%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row0_col1" class="data row0 col1" >0%~0%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row0_col2" class="data row0 col2" >0%~0%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row0_col3" class="data row0 col3" >0%~0%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row0_col4" class="data row0 col4" >0%~3%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row0_col5" class="data row0 col5" >1%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_de4a579c_a682_11ea_a5c3_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row1_col0" class="data row1 col0" >0%~0%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row1_col1" class="data row1 col1" >0%~0%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row1_col2" class="data row1 col2" >0%~1%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row1_col3" class="data row1 col3" >1%~3%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row1_col4" class="data row1 col4" >3%~23%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row1_col5" class="data row1 col5" >12%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_de4a579c_a682_11ea_a5c3_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row2_col0" class="data row2 col0" >0%~1%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row2_col1" class="data row2 col1" >1%~2%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row2_col2" class="data row2 col2" >2%~3%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row2_col3" class="data row2 col3" >3%~6%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row2_col4" class="data row2 col4" >8%~38%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row2_col5" class="data row2 col5" >15%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_de4a579c_a682_11ea_a5c3_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row3_col0" class="data row3 col0" >0%~0%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row3_col1" class="data row3 col1" >0%~2%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row3_col2" class="data row3 col2" >0%~2%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row3_col3" class="data row3 col3" >0%~3%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row3_col4" class="data row3 col4" >1%~32%</td>
#                         <td id="T_de4a579c_a682_11ea_a5c3_acbc32839263row3_col5" class="data row3 col5" >4%~100%</td>
#             </tr>
#     </tbody></table>

# %%
effectiveness_peak_table_iso(baseline,timing=False)
# Out:
# <style  type="text/css" >
#     #T_fd0db9b2_a682_11ea_a5c3_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_fd0db9b2_a682_11ea_a5c3_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_fd0db9b2_a682_11ea_a5c3_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263" ><caption>Placeholder</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>isolate symptomatically infected people at 100 people per day for 20 days</th>        <th class="col_heading level0 col2" colspan=2>isolate symptomatically infected people at 100 people per day for 30 days</th>        <th class="col_heading level0 col4" colspan=2>isolate symptomatically infected people at 50 people per day for 40 days</th>        <th class="col_heading level0 col6" colspan=2>isolate symptomatically infected people at 100 people per day for 60 days</th>        <th class="col_heading level0 col8" colspan=2>isolate symptomatically infected people at 10 people per day for 100 days</th>        <th class="col_heading level0 col10" colspan=2>isolate symptomatically infected people at 10 people per day for 200 days</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col1" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col2" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col3" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col4" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col5" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col6" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col7" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col8" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col9" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col10" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col11" >Reduction in Peak Number IQR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263level0_row0" class="row_heading level0 row0" >Prevalence of Symptomatic Cases</th>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row0_col0" class="data row0 col0" >17~23 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row0_col1" class="data row0 col1" >0%~0%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row0_col2" class="data row0 col2" >25~34 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row0_col3" class="data row0 col3" >0%~0%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row0_col4" class="data row0 col4" >33~44 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row0_col5" class="data row0 col5" >0%~0%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row0_col6" class="data row0 col6" >48~65 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row0_col7" class="data row0 col7" >2%~3%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row0_col8" class="data row0 col8" >71~102 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row0_col9" class="data row0 col9" >2%~4%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row0_col10" class="data row0 col10" >-46~112 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row0_col11" class="data row0 col11" >17%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263level0_row1" class="row_heading level0 row1" >Hospitalisation Demand</th>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row1_col0" class="data row1 col0" >17~23 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row1_col1" class="data row1 col1" >0%~0%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row1_col2" class="data row1 col2" >25~34 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row1_col3" class="data row1 col3" >0%~0%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row1_col4" class="data row1 col4" >33~44 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row1_col5" class="data row1 col5" >0%~0%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row1_col6" class="data row1 col6" >49~65 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row1_col7" class="data row1 col7" >0%~2%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row1_col8" class="data row1 col8" >71~102 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row1_col9" class="data row1 col9" >0%~3%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row1_col10" class="data row1 col10" >-35~124 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row1_col11" class="data row1 col11" >9%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Care Demand</th>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row2_col0" class="data row2 col0" >17~24 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row2_col1" class="data row2 col1" >0%~0%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row2_col2" class="data row2 col2" >25~34 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row2_col3" class="data row2 col3" >0%~0%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row2_col4" class="data row2 col4" >33~44 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row2_col5" class="data row2 col5" >0%~0%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row2_col6" class="data row2 col6" >49~65 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row2_col7" class="data row2 col7" >0%~0%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row2_col8" class="data row2 col8" >70~102 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row2_col9" class="data row2 col9" >0%~12%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row2_col10" class="data row2 col10" >-19~122 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row2_col11" class="data row2 col11" >10%~100%</td>
#             </tr>
#             <tr>
#                         <th id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263level0_row3" class="row_heading level0 row3" >Prevalence of Deaths</th>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row3_col0" class="data row3 col0" >18~23 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row3_col1" class="data row3 col1" >0%~0%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row3_col2" class="data row3 col2" >26~34 days</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row3_col3" class="data row3 col3" >0%~0%</td>
#                         <td id="T_fd0db9b2_a682_11ea_a5c3_acbc32839263row3_col4" class="data row3 col4" >34~44 days</td>
#                         <td id="T

# %%
plot_iso_intervention_horizontal(baseline,timing=False)

# %%
plot_iso_intervention_horizontal(baseline,column='Quarantined',timing=False)

# %%
plot_onetype_intervention_vertical('isolate50','Infected (symptomatic)')

# %%
plot_onetype_intervention_vertical('iso','Infected (symptomatic)')

# %% [markdown]
# ### 2.1.3 Build up ICU bed capacity

# %%
effectiveness_cum_table_onetype(baseline,'icu')
# Out:
# <style  type="text/css" >
#     #T_e4d57baa_a443_11ea_bf5b_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_e4d57baa_a443_11ea_bf5b_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_e4d57baa_a443_11ea_bf5b_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }    #T_e4d57baa_a443_11ea_bf5b_acbc32839263row0_col0 {
#             background-color:  green;
#         }    #T_e4d57baa_a443_11ea_bf5b_acbc32839263row0_col1 {
#             background-color:  green;
#         }    #T_e4d57baa_a443_11ea_bf5b_acbc32839263row0_col2 {
#             background-color:  green;
#         }    #T_e4d57baa_a443_11ea_bf5b_acbc32839263row1_col0 {
#             background-color:  green;
#         }    #T_e4d57baa_a443_11ea_bf5b_acbc32839263row1_col1 {
#             background-color:  0;
#         }    #T_e4d57baa_a443_11ea_bf5b_acbc32839263row1_col2 {
#             background-color:  0;
#         }    #T_e4d57baa_a443_11ea_bf5b_acbc32839263row2_col0 {
#             background-color:  green;
#         }    #T_e4d57baa_a443_11ea_bf5b_acbc32839263row2_col1 {
#             background-color:  0;
#         }    #T_e4d57baa_a443_11ea_bf5b_acbc32839263row2_col2 {
#             background-color:  0;
#         }    #T_e4d57baa_a443_11ea_bf5b_acbc32839263row3_col0 {
#             background-color:  0;
#         }    #T_e4d57baa_a443_11ea_bf5b_acbc32839263row3_col1 {
#             background-color:  green;
#         }    #T_e4d57baa_a443_11ea_bf5b_acbc32839263row3_col2 {
#             background-color:  green;
#         }</style><table id="T_e4d57baa_a443_11ea_bf5b_acbc32839263" ><caption>Table 3. Cumulative case counts of different disease states of COVID19</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >increase ICU capacity from 6 to 12</th>        <th class="col_heading level0 col1" >increase ICU capacity from 6 to 24</th>        <th class="col_heading level0 col2" >increase ICU capacity from 6 to 48</th>    </tr>    <tr>        <th class="index_name level0" >Total</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e4d57baa_a443_11ea_bf5b_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_e4d57baa_a443_11ea_bf5b_acbc32839263row0_col0" class="data row0 col0" >0%~0%</td>
#                         <td id="T_e4d57baa_a443_11ea_bf5b_acbc32839263row0_col1" class="data row0 col1" >0%~0%</td>
#                         <td id="T_e4d57baa_a443_11ea_bf5b_acbc32839263row0_col2" class="data row0 col2" >0%~0%</td>
#             </tr>
#             <tr>
#                         <th id="T_e4d57baa_a443_11ea_bf5b_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_e4d57baa_a443_11ea_bf5b_acbc32839263row1_col0" class="data row1 col0" >-2%~-2%</td>
#                         <td id="T_e4d57baa_a443_11ea_bf5b_acbc32839263row1_col1" class="data row1 col1" >-4%~-3%</td>
#                         <td id="T_e4d57baa_a443_11ea_bf5b_acbc32839263row1_col2" class="data row1 col2" >-4%~-3%</td>
#             </tr>
#             <tr>
#                         <th id="T_e4d57baa_a443_11ea_bf5b_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_e4d57baa_a443_11ea_bf5b_acbc32839263row2_col0" class="data row2 col0" >-40%~-38%</td>
#                         <td id="T_e4d57baa_a443_11ea_bf5b_acbc32839263row2_col1" class="data row2 col1" >-66%~-57%</td>
#                         <td id="T_e4d57baa_a443_11ea_bf5b_acbc32839263row2_col2" class="data row2 col2" >-66%~-57%</td>
#             </tr>
#             <tr>
#                         <th id="T_e4d57baa_a443_11ea_bf5b_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_e4d57baa_a443_11ea_bf5b_acbc32839263row3_col0" class="data row3 col0" >6%~7%</td>
#                         <td id="T_e4d57baa_a443_11ea_bf5b_acbc32839263row3_col1" class="data row3 col1" >8%~10%</td>
#                         <td id="T_e4d57baa_a443_11ea_bf5b_acbc32839263row3_col2" class="data row3 col2" >8%~10%</td>
#             </tr>
#     </tbody></table>

# %%
effectiveness_peak_table_onetype(baseline,'icu')
# Out:
# <style  type="text/css" >
#     #T_f296c7a8_a443_11ea_bf5b_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_f296c7a8_a443_11ea_bf5b_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_f296c7a8_a443_11ea_bf5b_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_f296c7a8_a443_11ea_bf5b_acbc32839263" ><caption>Table 3. Cumulative case counts of different disease states of COVID19</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>increase ICU capacity from 6 to 48</th>        <th class="col_heading level0 col2" colspan=2>increase ICU capacity from 6 to 12</th>        <th class="col_heading level0 col4" colspan=2>increase ICU capacity from 6 to 24</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col1" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col2" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col3" >Reduction in Peak Number IQR</th>        <th class="col_heading level1 col4" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col5" >Reduction in Peak Number IQR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f296c7a8_a443_11ea_bf5b_acbc32839263level0_row0" class="row_heading level0 row0" >Incidence of Symptomatic Cases</th>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row0_col0" class="data row0 col0" >0~0 days</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row0_col1" class="data row0 col1" >0%~0%</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row0_col2" class="data row0 col2" >0~0 days</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row0_col3" class="data row0 col3" >0%~0%</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row0_col4" class="data row0 col4" >0~0 days</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row0_col5" class="data row0 col5" >0%~0%</td>
#             </tr>
#             <tr>
#                         <th id="T_f296c7a8_a443_11ea_bf5b_acbc32839263level0_row1" class="row_heading level0 row1" >Hospitalisation Demand</th>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row1_col0" class="data row1 col0" >0~0 days</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row1_col1" class="data row1 col1" >-2%~-2%</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row1_col2" class="data row1 col2" >0~0 days</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row1_col3" class="data row1 col3" >-2%~-2%</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row1_col4" class="data row1 col4" >0~0 days</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row1_col5" class="data row1 col5" >-2%~-2%</td>
#             </tr>
#             <tr>
#                         <th id="T_f296c7a8_a443_11ea_bf5b_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Care Demand</th>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row2_col0" class="data row2 col0" >6~7 days</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row2_col1" class="data row2 col1" >-100%~-88%</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row2_col2" class="data row2 col2" >0~2 days</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row2_col3" class="data row2 col3" >-62%~-40%</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row2_col4" class="data row2 col4" >6~7 days</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row2_col5" class="data row2 col5" >-100%~-88%</td>
#             </tr>
#             <tr>
#                         <th id="T_f296c7a8_a443_11ea_bf5b_acbc32839263level0_row3" class="row_heading level0 row3" >Incidence of Deaths</th>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row3_col0" class="data row3 col0" >7~7 days</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row3_col1" class="data row3 col1" >0%~50%</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row3_col2" class="data row3 col2" >1~2 days</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row3_col3" class="data row3 col3" >0%~50%</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row3_col4" class="data row3 col4" >7~7 days</td>
#                         <td id="T_f296c7a8_a443_11ea_bf5b_acbc32839263row3_col5" class="data row3 col5" >0%~50%</td>
#             </tr>
#     </tbody></table>

# %%
plot_onetype_intervention_horizontal(baseline,'icu','Deaths')

# %%
plot_onetype_intervention_vertical('icu','Deaths')

# %% [markdown]
# ### 2.1.4 Shielding

# %%
effectiveness_cum_table_onetype(baseline,'shielding')
# Out:
# <style  type="text/css" >
#     #T_23ccc8f4_a444_11ea_bf5b_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_23ccc8f4_a444_11ea_bf5b_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_23ccc8f4_a444_11ea_bf5b_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }    #T_23ccc8f4_a444_11ea_bf5b_acbc32839263row0_col0 {
#             background-color:  green;
#         }    #T_23ccc8f4_a444_11ea_bf5b_acbc32839263row1_col0 {
#             background-color:  green;
#         }    #T_23ccc8f4_a444_11ea_bf5b_acbc32839263row2_col0 {
#             background-color:  green;
#         }    #T_23ccc8f4_a444_11ea_bf5b_acbc32839263row3_col0 {
#             background-color:  green;
#         }</style><table id="T_23ccc8f4_a444_11ea_bf5b_acbc32839263" ><caption>Table 3. Cumulative case counts of different disease states of COVID19</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >shielding</th>    </tr>    <tr>        <th class="index_name level0" >Total</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23ccc8f4_a444_11ea_bf5b_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_23ccc8f4_a444_11ea_bf5b_acbc32839263row0_col0" class="data row0 col0" >-13%~-4%</td>
#             </tr>
#             <tr>
#                         <th id="T_23ccc8f4_a444_11ea_bf5b_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_23ccc8f4_a444_11ea_bf5b_acbc32839263row1_col0" class="data row1 col0" >-10%~-7%</td>
#             </tr>
#             <tr>
#                         <th id="T_23ccc8f4_a444_11ea_bf5b_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_23ccc8f4_a444_11ea_bf5b_acbc32839263row2_col0" class="data row2 col0" >5%~8%</td>
#             </tr>
#             <tr>
#                         <th id="T_23ccc8f4_a444_11ea_bf5b_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_23ccc8f4_a444_11ea_bf5b_acbc32839263row3_col0" class="data row3 col0" >-17%~-6%</td>
#             </tr>
#     </tbody></table>

# %%
effectiveness_peak_table_shielding(baseline)
# Out:
# <style  type="text/css" >
#     #T_28f9d218_a444_11ea_bf5b_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_28f9d218_a444_11ea_bf5b_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_28f9d218_a444_11ea_bf5b_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_28f9d218_a444_11ea_bf5b_acbc32839263" ><caption>Table 3. Cumulative case counts of different disease states of COVID19</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=2>shielding</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >Delay in Peak Day IQR</th>        <th class="col_heading level1 col1" >Reduction in Peak Number IQR</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_28f9d218_a444_11ea_bf5b_acbc32839263level0_row0" class="row_heading level0 row0" >Incidence of Symptomatic Cases</th>
#                         <td id="T_28f9d218_a444_11ea_bf5b_acbc32839263row0_col0" class="data row0 col0" >-31~-20 days</td>
#                         <td id="T_28f9d218_a444_11ea_bf5b_acbc32839263row0_col1" class="data row0 col1" >-84%~-55%</td>
#             </tr>
#             <tr>
#                         <th id="T_28f9d218_a444_11ea_bf5b_acbc32839263level0_row1" class="row_heading level0 row1" >Hospitalisation Demand</th>
#                         <td id="T_28f9d218_a444_11ea_bf5b_acbc32839263row1_col0" class="data row1 col0" >-32~-20 days</td>
#                         <td id="T_28f9d218_a444_11ea_bf5b_acbc32839263row1_col1" class="data row1 col1" >-59%~-33%</td>
#             </tr>
#             <tr>
#                         <th id="T_28f9d218_a444_11ea_bf5b_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Care Demand</th>
#                         <td id="T_28f9d218_a444_11ea_bf5b_acbc32839263row2_col0" class="data row2 col0" >-32~-20 days</td>
#                         <td id="T_28f9d218_a444_11ea_bf5b_acbc32839263row2_col1" class="data row2 col1" >-20%~-12%</td>
#             </tr>
#             <tr>
#                         <th id="T_28f9d218_a444_11ea_bf5b_acbc32839263level0_row3" class="row_heading level0 row3" >Incidence of Deaths</th>
#                         <td id="T_28f9d218_a444_11ea_bf5b_acbc32839263row3_col0" class="data row3 col0" >-32~-19 days</td>
#                         <td id="T_28f9d218_a444_11ea_bf5b_acbc32839263row3_col1" class="data row3 col1" >-50%~0%</td>
#             </tr>
#     </tbody></table>

# %%
plot_onetype_intervention_horizontal(baseline,'shielding','Deaths')

# %%
#distill each predominant feature from each intervention to design something that can have the best impact

# %%
plot_intervention_comparison_interactive(plot_intervention_comparison,baseline)
# Out:
# VBox(children=(Label(value='Compare two different intervention strategies or compare a particular intervention…

# %% [markdown]
# ### 2.2 Onto designing multi-intervention strategies

# %% [markdown]
# A version of intervention could be:
#
# Invest in a prolonged programme in improving personal hygiene for the camp residents in the whole duration of the pandemic
#
# Move high risk residents swiftly off the island at the very start of the epidemic
#
# Ask the residents who are infected to minimise their contacts and movement and make sure they have access to the necessary treatment (including ICU bed on the island if need be)

# %% [markdown]
# (draft conclusion) Here we explore the effect of a single intervention and the combination of one,two,three,four or even five interventions altogether. It should become clear that though some interventions are more effective than others in driving down peak counts, a combination of effective intervention strategy is the best

# %%
effectiveness_cum_table_custom(baseline,caption='Custom intervention pathway demonstration',display=False)
# Out:
# <style  type="text/css" >
#     #T_7dab54dc_a58c_11ea_9b7b_acbc32839263 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_7dab54dc_a58c_11ea_9b7b_acbc32839263 td {
#           font-size: 15px;
#           text-align: center;
#     }    #T_7dab54dc_a58c_11ea_9b7b_acbc32839263 caption {
#           font-size: 15px;
#           text-align: center;
#     }</style><table id="T_7dab54dc_a58c_11ea_9b7b_acbc32839263" ><caption>Custom intervention pathway demonstration</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >hygieneisohighrisk</th>    </tr>    <tr>        <th class="index_name level0" >Total</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7dab54dc_a58c_11ea_9b7b_acbc32839263level0_row0" class="row_heading level0 row0" >Symptomatic Cases</th>
#                         <td id="T_7dab54dc_a58c_11ea_9b7b_acbc32839263row0_col0" class="data row0 col0" >9%~58%</td>
#             </tr>
#             <tr>
#                         <th id="T_7dab54dc_a58c_11ea_9b7b_acbc32839263level0_row1" class="row_heading level0 row1" >Hospital Person-Days</th>
#                         <td id="T_7dab54dc_a58c_11ea_9b7b_acbc32839263row1_col0" class="data row1 col0" >31%~85%</td>
#             </tr>
#             <tr>
#                         <th id="T_7dab54dc_a58c_11ea_9b7b_acbc32839263level0_row2" class="row_heading level0 row2" >Critical Person-days</th>
#                         <td id="T_7dab54dc_a58c_11ea_9b7b_acbc32839263row2_col0" class="data row2 col0" >15%~87%</td>
#             </tr>
#             <tr>
#                         <th id="T_7dab54dc_a58c_11ea_9b7b_acbc32839263level0_row3" class="row_heading level0 row3" >Deaths</th>
#                         <td id="T_7dab54dc_a58c_11ea_9b7b_acbc32839263row3_col0" class="data row3 col0" >35%~93%</td>
#             </tr>
#     </tbody></table>

# %%
plot_intervention_comparison_interactive(plot_intervention_comparison,baseline,folder_path='./model_outcomes/custom/')
# Out:
# VBox(children=(Label(value='Compare two different intervention strategies or compare a particular intervention…

# %% [markdown]
# #TODO:
# 1. Add percentages to the cumulative cases to signify what is the proportion of people getting something
# 2. Add asymptomatic infections count to the table
